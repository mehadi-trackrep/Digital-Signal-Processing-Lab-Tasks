# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ### Task#02: Create a Sinusoidal Signal y(n) and plot the signal.

# %%
t=np.arange(0.0,100,0.01)
y=sinWave(5,10,t)
plt.plot(t,y, 'm')
plt.show()

# %% [markdown]
# ### Task#03: Create 3 Sinusoidal signal y1, y2, y3. then combine them and plot it.

# %%
t=np.arange(0.0,100,0.01)

plt.subplot(2,2,1)
y1=sinWave(5,10,t)
plt.plot(t,y1, 'r')

plt.subplot(2,2,2)
y2=sinWave(5,20,t)
plt.plot(t,y2, 'b')

plt.subplot(2,2,3)
y3=sinWave(5,25,t)
plt.plot(t,y3, 'g')

plt.show()

y=y1+y2+y3
plt.plot(t,y, 'o')
plt.show()

# %% [markdown]
# ### Task#04: Plot the basic signals like unit impulse, unit samples, unit step, exponential, unit ramp (discussed in classes) etc.

# %%
fig = plt.figure(figsize= [20,10])
###Unit Impulse
t=np.arange(-20,20,1)
y=[]
mid=0
for x in t:
    if x==mid:
        y.append(1)
    else:
        y.append(0)
plt.subplot(2,2,1)      
plt.title("Unit Impulse")
plt.stem(t,y)

###unit Step
t1=np.arange(-20,20,1)
y1=[]
for x in t1:
    if x>=0:
        y1.append(1)     
    else:
        y1.append(0)
plt.subplot(2,2,2)       
plt.title("Unit Step")
plt.stem(t1,y1)

###unit Exponential
t2=np.arange(-20,20,0.1)
y2=[]
for x in t2:
    y2.append(np.exp(x))
plt.subplot(2,2,3)       
plt.title("Exponential")
plt.plot(t2,y2)

###unit ramp
t3=np.arange(-20,20,0.1)
y3=[]
for x in t3:
    if x>=0:
        y3.append(x)
    else:
        y3.append(0)
plt.subplot(2,2,4)       
plt.title("Ramp")
plt.stem(t3,y3, 'c')

plt.show()

# %% [markdown]
# ### Task#05: Sampling of a Signal... take a signal then sample using a sampling rate.

# %%
def SubPloting(nrows,ncols,index,t,y,color,title,xlabel,ylabel,markersize,show):
    plt.subplot(nrows,ncols,index)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    l=plt.plot(t,y,color)
    if markersize > 0:
        plt.setp(l,markersize=markersize)
    if show==1:
        plt.show()

# %%
fig = plt.figure(figsize= [20,10])
T=10
f=1/T
fs=2*f

t=np.arange(0.0, 50, 0.01)
y=sinWave(5,10,t)
SubPloting(2,2,1,t,y,'b',"Main Signal",'','',0,0)

# fs = fs-0.05
fs = fs+1
tdif = 1/fs
t=np.arange(0.0, 50, tdif)
y=sinWave(5,T,t)
markersize=10
SubPloting(2,2,2,t,y,'ro',"After Sampling",'','',markersize,1)

# %% [markdown]
# ### Task#06: Sampling Theorem Experiment.

# %%
fig = plt.figure(figsize= [20,10])
T=10
f=1/T
fs=2*f

t=np.arange(0.0, 50, 0.01)
y=sinWave(5,10,t)
SubPloting(2,2,1,t,y,'b',"Main Signal",'Time =>','Amplitue =>',0,0)

# fs = fs-0.05
fs = fs+0.1
tdif = 1/fs
t=np.arange(0.0, 50, tdif)
y=sinWave(5,T,t)
markersize=10
SubPloting(2,2,2,t,y,'ro',"After Sampling",'Time =>','Amplitue =>',markersize,1)

# %% [markdown]
# ### Task#07: Implement some basic systems like Adder, Multiplier, Delay, Advanced, Fold etc.

# %%
def Adder(x1,x2):
    l = len(x1)
    y = []
    for i in range(l):
        y.append(x1[i] + x2[i])
    return y

        
def Multiplier(mul, x):
    l = len(x)
    y = []
    for i in range(l):
        y.append( (x[i]) * mul )
    return y

def Delay(d, x):
    l = len(x)
    y = []
    for i in range(l):
        y.append(x[i])
    for i in range(d):
        y.append(0)
    return y

def Advance(a, x):
    l = len(x)
    y = []
    for i in range(a):
        y.append(0)
    for i in range(l):
        y.append(x[i])
    return y

def Fold(x):
    return x[::-1]

x1 = [1,2,3,4]
x2 = [4,3,2,1]
x  = [1,2,3,4]
d = 2
mul = 5
a = 2

print("Adder: ",Adder(x1,x2))
print("Multiplier: ",Multiplier(mul, x))
print("Delay: ",Delay(d, x))
print("Advance: ",Advance(a, x))
print("Fold: ",Fold(x))
# Out:
# Adder:  [5, 5, 5, 5]
# Multiplier:  [5, 10, 15, 20]
# Delay:  [1, 2, 3, 4, 0, 0]
# Advance:  [0, 0, 1, 2, 3, 4]
# Fold:  [4, 3, 2, 1]

# %% [markdown]
# ### Task#08: Implement Moving average filter, Median Filter, Accumulator etc.

# %%
import os
import sys
import seaborn
from scipy.signal import medfilt

# %%
def movingaverage(values,window):
    weigths = np.repeat(1.0, window)/window
    m = np.convolve(values, weigths, 'valid')
    #print ("m: ",m)
    return m

signal = [1,6,3,13,5,6,7,10,9,4,6,5,7]

plt.subplot(2,2,1)       
plt.title("Moving Average")
plt.plot(movingaverage(signal,3), 'r-')
plt.show()

def median_filter(data):
    return medfilt(data, kernel_size=3)

plt.subplot(2,2,1)       
plt.title("Median Filter")
plt.plot(median_filter(signal), 'r-')
plt.show()

# %% [markdown]
# ### Task#09: Convolution

# %%
import scipy.signal
hn=[1,2,1,-1]
xn=[1,2,3,1]
x=scipy.signal.convolve(hn,xn, 'full')
plt.stem(x,'r-')
plt.show()

# %% [markdown]
# ### Task#10: program to find the DFT/IDFT

# %%
import numpy.fft as DFT ### Getting DFT using fft
N = 100
f=1/10
t = np.linspace(0,20,N)
x = np.sin(2*np.pi*f*t)

y = DFT.fftn(x, norm='ortho')
window = np.zeros(N)
window[:20] = 1
yr = DFT.ifftn(y*window, norm='ortho')

plt.plot(t, x, '-bx')
plt.plot(t, yr, 'ro')
plt.show()
# Out:
# /home/hasanmdmehadi/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ### Tasks#11: DFT/IDFT -> Composite Sinusoidal Signal to see the frequencies

# %%
import numpy.fft as DFT ### Getting DFT using fft
N = 100
f=1/10
t = np.linspace(0,20,N)
x = np.sin(2*np.pi*f*t) + np.exp(-t/3)*np.cos(2*np.pi*f*t) ##Composite signal

y = DFT.fftn(x, norm='ortho')
window = np.zeros(N)
window[:20] = 1
yr = DFT.ifftn(y*window, norm='ortho')

plt.plot(t, x, '-bx')
plt.plot(t, yr, 'ro')
plt.show()
# Out:
# /home/hasanmdmehadi/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ### Task#12: Read a .wav, img file and plot them, play / open them. Then apply DFT.

# %%
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
from scipy.fftpack import fft
import numpy as np


#### READ WAV FILE === 
sample_rate, data = wav.read('test.wav')

times = np.arange (len(data))/(float(sample_rate)) ## getting time of each sample ...

plt.figure(figsize=(30, 6))
plt.fill_between(times, data, color='g')
plt.xlabel('Time(t) ==> ')
plt.ylabel('Amplitude(A) ==> ')
plt.show()

plt.savefig('plot.png', dpi=100)

fft_out = fft(data)
# %matplotlib inline
plt.plot(data, np.abs(fft_out))
plt.show()

# %%
import numpy, scipy, sklearn, librosa, urllib, IPython.display
import matplotlib.pyplot as plt
# plt.rcParams['figure.figsize'] = (14,4)
import librosa.display
x, fs = librosa.load('test.wav', duration=10)
librosa.display.waveplot(x, sr=fs, color='r', alpha=0.5)
IPython.display.Audio(x, rate=fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### image plot

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('test.jpg')
imgplot = plt.imshow(img)
plt.colorbar()

# %%
from scipy import signal, misc
import numpy as np
image = misc.face(gray=True).astype(np.float32)
plt.figure()
plt.imshow(image)
plt.gray()
plt.title('Original image')
plt.show()

# %%
##DFT (Filtering)
w = np.zeros((50, 50))
w[0][0] = 1.0
w[49][25] = 1.0
image_new = signal.fftconvolve(image, w)
plt.figure()
plt.imshow(image_new)
plt.gray()
plt.title('Filtered image')
plt.show()

# %% [markdown]
# ### Task#13:  Linear Convolution

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig

L = 32  # length of signal x[k]
N = 16  # length of signal h[k]
M = 16  # periodicity of periodic convolution


def cconv(x, h, M):
    L = len(x)
    N = len(h)
    # periodic continuation of x
    xc = np.copy(x)
    if M<L:
        xc[0:-M+L] += xc[M:L]
        xc = xc[0:M]
    # zero-padding of h
    hp = h
    if N<M:
        hp = np.append(hp, np.zeros(M-N))
    # circular convolution
    y = [np.dot(np.roll(xc[::-1], k+1), hp) for k in np.arange(M)]

    return np.asarray(y)

# generate signals
x = np.ones(L)
h = sig.triang(N)

# linear convolution
y1 = np.convolve(x, h, 'full')

# plot results
def plot_signal(x):
    plt.figure(figsize = (10, 3))
    plt.stem(x)
    plt.xlabel(r'$k$')
    plt.ylabel(r'$y[k]$')
    plt.axis([0, N+L, 0, 1.1*x.max()])

plot_signal(x)
plt.title('Signal $x[k]$')

plot_signal(y1)
plt.title('Linear convolution')

# %% [markdown]
# ### Task#14: Circular Convolution Program

# %%
# periodic convolution
y2 = cconv(x, h, M)

plot_signal(y2)
plt.title('Periodic convolution')

# %% [markdown]
# ### Task#15: Linear Convolution by FFT, IFFT [DFT, IDFT]

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig

L = 16  # length of signal x[k]
N = 16  # length of signal h[k]
M = N+L-1

# generate signals
x = np.ones(L)
h = sig.triang(N)

# fast convolution
y2 = np.fft.ifft(np.fft.fft(x, M)*np.fft.fft(h, M))

plt.figure(figsize=(10, 3))
plt.stem(y2)
plt.xlabel(r'k')
plt.ylabel(r'|e[k]|');
# Out:
# /home/hasanmdmehadi/anaconda3/envs/my_env/lib/python3.6/site-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ### Task#16: Circular Convolution by FFT, IFFT [DFT, IDFT]

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig

L = 16  # length of signal x[k]
N = 16  # length of signal h[k]
M = N+L-1

# generate signals
x = np.ones(L)
h = sig.triang(N)

def circular_conv():
    return np.fft.ifft(np.fft.fft(x, M)*np.fft.fft(h, M))

y = circular_conv()

plt.figure(figsize=(10, 3))
plt.title("-- Circular Convolution using FFT, IFFT --")
plt.stem(y)
plt.xlabel(r'k')
plt.ylabel(r'|e[k]|');
# Out:
# /home/hasanmdmehadi/anaconda3/envs/my_env/lib/python3.6/site-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ### Task17# FIR Filter Low Pass

# %%
from pylab import *
import scipy.signal as signal

#Plot frequency and phase response
def mfreqz(b,a=1):
    w,h = signal.freqz(b,a)
    h_dB = 20 * log10 (abs(h))
    subplot(211)
    plot(w/max(w),h_dB)
    ylim(-150, 5)
    ylabel('Magnitude (db)')
    xlabel(r'Normalized Frequency (x$\pi$rad/sample)')
    title(r'Frequency response')
    subplot(212)
    h_Phase = unwrap(arctan2(imag(h),real(h)))
    plot(w/max(w),h_Phase)
    ylabel('Phase (radians)')
    xlabel(r'Normalized Frequency (x$\pi$rad/sample)')
    title(r'Phase response')
    subplots_adjust(hspace=0.5)

#Plot step and impulse response
def impz(b,a=1):
    l = len(b)
    impulse = repeat(0.,l); impulse[0] =1.
    x = arange(0,l)
    response = signal.lfilter(b,a,impulse)
    subplot(211)
    stem(x, response)
    ylabel('Amplitude')
    xlabel(r'n (samples)')
    title(r'Impulse response')
    subplot(212)
    step = cumsum(response)
    stem(x, step)
    ylabel('Amplitude')
    xlabel(r'n (samples)')
    title(r'Step response')
    subplots_adjust(hspace=0.5)
n = 61
a = signal.firwin(n, cutoff = 0.3, window = "hamming")
#Frequency and phase response
mfreqz(a)

# %% [markdown]
# ### Task18# FIR Filter High Pass

# %%
n = 101
a = signal.firwin(n, cutoff = 0.3, window = "hanning", pass_zero=False)
mfreqz(a)
show()

# %% [markdown]
# ### Task19# FIR Filter Band Pass and Band Reject Filter

# %%
n = 1001
## Band Pass Filter
a = signal.firwin(n, cutoff = [0.2, 0.5], window = 'flattop', pass_zero = False)
mfreqz(a)
show()
## Band Reject Filter
# bohman
a = signal.firwin(n, cutoff = [0.2, 0.5], window = 'blackmanharris', pass_zero = True)
mfreqz(a)
show()

# %% [markdown]
# ### Task20# IIR Filter Low Pass

# %%
from numpy import *
from scipy import signal
from scipy.signal import filter_design as fd
from matplotlib import pyplot as plt

Wp = 0.412  
Ws = 0.270   
Rp = 0.1   
As = 60 

Filters = {'moving' : (), 'butter' : ()}

Filters['butter'] = fd.iirdesign(Ws, Wp, Rp, As, ftype='butter')
Filters['chebyshev'] = fd.iirdesign(Ws, Wp, Rp, As, ftype='cheby1')

plt.plot(Filters['chebyshev'])
plt.show()

# %% [markdown]
# ### Task21# IIR Filter High Pass

# %%
from numpy import *
from scipy import signal
from scipy.signal import filter_design as fd
from matplotlib import pyplot as plt

Wp = 0.412   
Ws = 0.270   
Rp = 0.1    
As = 60     

Filters = {'chebyshev' : (), 'butter' : ()}

Filters['butter'] = fd.iirdesign(Wp, Ws, Rp, As, ftype='butter')
Filters['chebyshev'] = fd.iirdesign(Wp, Ws, Rp, As, ftype='cheby1')

plt.plot(Filters['chebyshev'])
plt.show()

# %% [markdown]
# ### Task#22: Read a .wav file -> MFCC

# %%
from python_speech_features import mfcc
from python_speech_features import logfbank
import scipy.io.wavfile as wav
(rate,sig) = wav.read("test.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
print(fbank_feat[1:3,:])
plt.plot(mfcc_feat)
plt.show()
# Out:
# WARNING:root:frame length (600) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (600) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# [[  5.0592151    2.8436091    4.84420447   4.66201261   4.21609214
#     4.86254831   5.02457608   5.57658049   5.87821278   6.15960537
#     6.75706386   6.99797097   6.95330916   7.44182083   7.73607539
#     7.7019594    8.20357333   8.60993398   8.44469679   8.67014647
#     9.61882668   9.5346187    9.70011416  10.47769201  10.26784882
#     9.66575097]
#  [  4.27240708   4.63399525   4.85757633   6.7373132    7.9601185
#     8.86350375   9.44999763   9.71149514   9.23116451   8.13617365
#     9.82814727  11.07137857  11.54520993  11.41253516  11.52333765
#    11.75664832  12.33039925  13.03742914  14.11210699  14.18850792
#    13.82886943  13.65637938  11.56625777  11.73868572  11.47343216
#    10.4199614 ]]

# %% [markdown]
# ### Or, using 'librosa' package-->

# %%
import numpy, scipy, sklearn, librosa, urllib, IPython.display
import matplotlib.pyplot as plt
# plt.rcParams['figure.figsize'] = (14,4)
import librosa.display

# %%
x, fs = librosa.load('test.wav', duration=10)
librosa.display.waveplot(x, sr=fs, color='r', alpha=0.5)
plt.show()

# %%
IPython.display.Audio(x, rate=fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mfccs = librosa.feature.mfcc(x, sr=fs)
mfccs = sklearn.preprocessing.scale(mfccs, axis=1)

# %%
librosa.display.specshow(mfccs, sr=fs, x_axis='time')
plt.show()

# %% [markdown]
# ### Task#23: Read an img file -> resize, reshape, flat (using numpy, openCV)

# %%
import cv2
import matplotlib.pyplot as plt
filename = 'test.jpg'
W = 1000.
oriimg = cv2.imread(filename,cv2.COLOR_BGR2GRAY)
height, width, depth = oriimg.shape
imgScale = W/width
newX,newY = oriimg.shape[1]*imgScale, oriimg.shape[0]*imgScale
newimg = cv2.resize(oriimg,(int(newX),int(newY)))
cv2.imshow("Show by CV2",newimg)
oriimg.shape
# Out:
# (288, 1008, 3)

# %% [markdown]
# ### Task#24: image -> gray scale, resize... other basic operations (openCV)

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('plot.png',0)

dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)

magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Task#25: Basic Image Processing Methods

# %%
import scipy.misc
face = scipy.misc.face()
print(face.shape)
print(face.max)
print(face.dtype)
plt.gray()
plt.imshow(face)
plt.show()

img=plt.imread('plot.png')
print(img[:1])
plt.axis("off")
imgplot = plt.imshow(img)
# Out:
# (768, 1024, 3)
# <built-in method max of numpy.ndarray object at 0x7ff7cc89ce90>
# uint8

# %%
import numpy as np
import matplotlib.pyplot as plt

def shade(imag, percent):
    tinted_imag = imag * (1 - percent)
    return tinted_imag

def vertical_gradient_line(image, reverse=False):
    number_of_columns = image.shape[1]
    if reverse:
        C = np.linspace(1, 0, number_of_columns)
    else:
        C = np.linspace(0, 1, number_of_columns)
    C = np.dstack((C, C, C))
    return C

def horizontal_gradient_line(image, reverse=False):
    number_of_rows, number_of_columns = image.shape[:2]
    C = np.linspace(1, 0, number_of_rows)
    C = C[np.newaxis,:]
    C = np.concatenate((C, C, C)).transpose()
    C = C[:, np.newaxis]
    return C

windmills = plt.imread('plot.png')
tinted_windmills = shade(windmills, 0.7)
plt.imshow(tinted_windmills)
plt.show()

# %%
horizontal_brush = horizontal_gradient_line(windmills)
tinted_windmills =  windmills * windmills
plt.imshow(tinted_windmills)
plt.show()

# %%
# %matplotlib inline
# from scipy import misc
# ascent = misc.ascent()
# import matplotlib.pyplot as plt
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('plot.png',0)
plt.plot(img)
plt.show()
plt.gray()
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Task#26: Speech Processing -> Filter, Convolution etc.

# %% [markdown]
# ### Task#27: Data Compression (text and image )

# %%
##Text data compression:
import base64
import zlib
data = b'2,3,5,1,13,7,17,11,89,1,233,29,61,47,1597,19,37,41,421,199,28657,23,3001,521,53,281,514229,31,557,2207,19801,3571,141961,107,73,9349,135721,2161,2789,211,433494437,43,109441,139,2971215073,1103,97,101,6376021,90481,953,5779,661,14503,797,59,353,2521,4513,3010349,35239681,1087,14736206161,9901,269,67,137,71,6673,103681,9375829,54018521,230686501,29134601,988681,79,157,1601,2269,370248451,99194853094755497,83,9521,6709,173,263,1069,181,741469,4969,4531100550901,6643838879,761,769,193,599786069,197,401,743519377,919,519121,103,8288823481,119218851371,1247833,11128427,827728777,331,1459000305513721,10745088481,677,229,1381,347,29717,709,159512939815855788121'
# compressed = '...'
# data = zlib.decompress(base64.b64decode(compressed))
compressed_data = base64.b64encode(zlib.compress(data))
print(compressed_data)
# print (data)
# Out:
# b'...'

# %%
#run this in any directory add -v for verbose 
#get Pillow (fork of PIL) from pip before running --> pip install Pillow

import os
import sys
from PIL import Image

def compressMe(file, verbose=False):
	filepath = os.path.join(os.getcwd(), file)
	oldsize = os.stat(filepath).st_size
	picture = Image.open(filepath)
	dim = picture.size
	
	#set quality= to the preferred quality. 
	#I found that 85 has no difference in my 6-10mb files and that 65 is the lowest reasonable number
	picture.save("Compressed_"+file,"JPEG",optimize=True,quality=85) 
	
	newsize = os.stat(os.path.join(os.getcwd(),"Compressed_"+file)).st_size
	percent = (oldsize-newsize)/float(oldsize)*100
	if (verbose):
		print ("File compressed from {0} to {1} or {2}%".format(oldsize,newsize,percent))
	return percent

def main():
	verbose = False
	#checks for verbose flag
	if (len(sys.argv)>1):
		if (sys.argv[1].lower()=="-v"):
			verbose = True

	#finds present working dir
	pwd = os.getcwd()

	tot = 0
	num = 0
	for file in os.listdir(pwd):
		if os.path.splitext(file)[1].lower() in ('.jpg', '.jpeg'):
			num += 1
			tot += compressMe(file, verbose)
	print ("Average Compression: %d" % (float(tot)/num))
	print ("Done")

if __name__ == "__main__":
	main()
# Out:
# Average Compression: 27
# Done

# %% [markdown]
# ### Task#28: DCT -> Application

# %%
# Out:
# 1000.0
# 3000.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-dc1d05cfb530> in <module>()
#      29 print (w)
#      30
# ---> 31 img1=img1[:h,:w]
#      32
#      33
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %% [markdown]
# ### Task#29: DWT -> Application

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-81-6d67005b7426> in <module>()
#       5
#       6 import pywt
# ----> 7 import pygasp.dwt.dwt as pygaspDWT
#       8 import pygasp.dwt.dwtCuda as pygaspDWTgpu
#       9
#
# ModuleNotFoundError: No module named 'pygasp'

# %% [markdown]
# # Current Trends:

# %% [markdown]
# ### Task#30: Signal Processing using NN(Neural Network) -> Basics

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-80-33147158bd97> in <module>()
# ----> 1 from data_generator import vis_train_features
#       2 # extract label and audio features for a single training example
#       3 vis_text, vis_raw_audio, vis_mfcc_feature, vis_spectrogram_feature, vis_audio_path = vis_train_features()
#
# ModuleNotFoundError: No module named 'data_generator'

# %% [markdown]
# ### Task#31: Signal Processing using CNN Basics

# %% [markdown]
# ### Task#32: Signal Processing using RNN Basics
